# %%
# Cell 1 - Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.preprocessing import StandardScaler

# %%
# Cell 2 - Load New Dataset
new_data = pd.read_csv('DiamondPricesNew.csv')
new_data.head()

# %%
# Cell 3 - Set Diamond as Index
new_data_process = new_data.set_index('Diamond')

# %%
# Cell 4 - Fill Missing Values
new_data_process['carat'] = new_data_process['carat'].fillna(new_data_process['carat'].mean())
new_data_process['cut'] = new_data_process['cut'].fillna(new_data_process['cut'].mode()[0])
new_data_process['color'] = new_data_process['color'].fillna(new_data_process['color'].mode()[0])
new_data_process['clarity'] = new_data_process['clarity'].fillna(new_data_process['clarity'].mode()[0])
new_data_process['depth'] = new_data_process['depth'].fillna(new_data_process['depth'].mean())
new_data_process['table'] = new_data_process['table'].fillna(new_data_process['table'].median())
new_data_process['x'] = new_data_process['x'].fillna(new_data_process['x'].mean())
new_data_process['y'] = new_data_process['y'].fillna(new_data_process['y'].mean())
new_data_process['z'] = new_data_process['z'].fillna(new_data_process['z'].mean())

# %%
# Cell 5 - Log Transformations
new_data_process['carat_log'] = np.log1p(new_data_process['carat'])
new_data_process['table_log'] = np.log1p(new_data_process['table'])
new_data_process['y_log'] = np.log1p(new_data_process['y'])# Cell 6 - Create Dummy Variables
new_data_dummy = pd.get_dummies(new_data_process, drop_first=True)
new_data_dummy.head()

# %%
# Cell 6 - Create Dummy Variables
new_data_dummy = pd.get_dummies(new_data_process, drop_first=True)
new_data_dummy.head()

# %%
# Cell 7 - Select Input Variables (must match Phase 1 columns)
input_new = new_data_dummy[['carat_log', 'table_log', 'x', 'y_log', 'z',
                             'color_E', 'color_F', 'color_G', 'color_H',
                             'color_I', 'color_J', 'cut_Good', 'cut_Ideal',
                             'cut_Premium', 'cut_Very Good',
                             'clarity_IF', 'clarity_SI1', 'clarity_SI2',
                             'clarity_VS1', 'clarity_VS2', 'clarity_VVS1',
                             'clarity_VVS2']]
input_new.head()

# %%
# Cell 8 - Feature Scaling
scaler = StandardScaler()
scaler.fit(input_new)
input_new_scaled = scaler.transform(input_new)

# %%
# Cell 9 - Load Saved Model
loaded_model = pickle.load(open('diamond_model.sav', 'rb'))

# %%
# Cell 10 - Predict
predict_output = loaded_model.predict(input_new_scaled)
predict_output = pd.DataFrame({'Predicted Price (USD)': np.around(predict_output, 2)},
                               index=new_data_process.index)

# %%
# Cell 11 - Display Predictions
predict_output.head()

# %%
# Cell 12 - Combine New Data with Predictions
new_predict = pd.concat([new_data, predict_output], axis=1)
new_predict.head()

# %%
# Cell 13 - Scatter Plot
plt.scatter(range(len(predict_output)), predict_output['Predicted Price (USD)'], color='steelblue')
plt.xlabel('Diamond', size=12)
plt.ylabel('Predicted Price (USD)', size=12)
plt.title('Gem.Co — Predicted Diamond Prices (Phase 2)')
plt.tight_layout()
plt.show()
# Cell 14 - Summary Statistics
print(predict_output.describe())

# %%
# Cell 15 - Save Predicted Output to CSV
new_predict.to_csv('DiamondPricesNew_Predicted.csv', index=False)
