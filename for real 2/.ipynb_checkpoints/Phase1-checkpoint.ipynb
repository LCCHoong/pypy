# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
traindf = pd.read_csv('DiamondPrices.csv')
#read data from csv

# %%
traindf
#display table
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3    NaN       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
# 53940       53941   0.71    Premium     E     SI1   60.5   55.0   2756  5.79
# 53941       53942   0.71    Premium   NaN     SI1   59.8   62.0   2756  5.74
# 53942       53943   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53938  6.12  3.74
# 53939  5.87  3.64
# 53940  5.74  3.49
# 53941  5.73  3.43
# 53942  5.76  3.47
#
# [53943 rows x 11 columns]

# %%
traindf.columns
#check column names
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='str')

# %%
traindf.describe()
#describe table
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53943.000000  51210.000000  51262.000000  51254.000000  53943.000000
# mean   26972.000000      0.797648     61.749467     57.461613   3932.734294
# std    15572.147122      0.474164      1.431262      2.234639   3989.338447
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13486.500000      0.400000     61.000000     56.000000    950.000000
# 50%    26972.000000      0.700000     61.800000     57.000000   2401.000000
# 75%    40457.500000      1.040000     62.500000     59.000000   5324.000000
# max    53943.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  51209.000000  51274.000000  51284.000000
# mean       5.733212      5.734110      3.538269
# std        1.121856      1.144095      0.706337
# min        0.000000      0.000000      0.000000
# 25%        4.720000      4.720000      2.910000
# 50%        5.700000      5.710000      3.520000
# 75%        6.540000      6.540000      4.030000
# max       10.740000     58.900000     31.800000

# %%
traindf = traindf.drop(columns = 'Unnamed: 0')
#drop unused column
traindf.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='str')

# %%
traindf = traindf[(traindf['x'] > 0) & (traindf['y'] > 0) & (traindf['z'] > 0)]
#remove rows where x = 0 , y = 0 ,z = 0 and nan

# %%
traindf.drop_duplicates(keep='first', inplace = True)

# %%
traindf.isnull().sum()
#check null value
# Out:
# carat      2366
# cut        2329
# color      2352
# clarity    2300
# depth      2289
# table      2303
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
traindf.dtypes
#check column types
# Out:
# carat      float64
# cut            str
# color          str
# clarity        str
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
traindf['cut'] = traindf['cut'].fillna(traindf['cut'].mode()[0])
traindf['cut'] = traindf['cut'].astype('category')
#fill empty value with mode since its a categorical value

# %%
traindf['color'] = traindf['color'].fillna(traindf['color'].mode()[0])
traindf['color'] = traindf['color'].astype('category')
#fill empty value with mode since its a categorical value

# %%
traindf['clarity'] = traindf['clarity'].fillna(traindf['clarity'].mode()[0])
traindf['clarity'] = traindf['clarity'].astype('category')
#fill empty value with mode since its a categorical value

# %%
traindf['depth'].skew()
#check skew to see if there is outlier
# Out:
# np.float64(-0.11714347697814916)

# %%
traindf['depth'] = traindf['depth'].fillna(traindf['depth'].mean())
#fill empty value with mean since its a numerical value

# %%
traindf['carat'] = traindf['carat'].fillna(traindf['carat'].mean())
#fill empty value with mean since its a numerical value

# %%
traindf['carat'] .skew()
# Out:
# np.float64(1.1467085036130915)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=traindf['carat'])
plt.show()

# %%
traindf['carat_log'] = np.log1p(traindf['carat'])
#deal with outlier

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=traindf['carat_log'])
plt.show()

# %%
traindf['carat_log'].skew()
# Out:
# np.float64(0.574518396930041)

# %%
traindf['table'].skew()
#check skew to see if there is outlier
# Out:
# np.float64(0.7187458927899647)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=traindf['table'])
plt.show()
#display plot

# %%
traindf['table'] = traindf['table'].fillna(traindf['table'].median())
#fill empty value with median since its a numerical value

# %%
traindf['table_log'] = np.log1p(traindf['table'])
#deal with outlier

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=traindf['table_log'])
plt.show()
#plot_ytraindf['y_log'] = np.log1p(traindf['y'])
#deal with outlier

# %%
traindf['table_log'].skew()
#check skew to see if there is outlier
# Out:
# np.float64(0.6107059183297914)

# %%
traindf['x'].skew()
#check skew to see if there is outlier
# Out:
# np.float64(0.3969221468850046)

# %%
plt.figure(figsize = (6,4))
sns.boxplot(x = traindf['x'])
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=traindf['y'])
plt.show()
#plot_y

# %%
traindf['y_log'] = np.log1p(traindf['y'])
#deal with outlier

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=traindf['y_log'])
plt.show()
#plot y_log

# %%
traindf['y_log'].skew()
#check skew
# Out:
# np.float64(0.16104498259079394)

# %%
traindf['z'].skew()
#check skew to see if there is outlier
# Out:
# np.float64(0.3928463044468916)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=traindf['z'])
plt.show()

# %%
traindf
# Out:
#           carat        cut color clarity  depth  table  price     x     y  \
# 0      0.230000      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1      0.210000    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2      0.797837       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3      0.290000    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4      0.310000       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...         ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53937  0.700000  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  0.860000    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  0.750000      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
# 53940  0.710000    Premium     E     SI1   60.5   55.0   2756  5.79  5.74
# 53942  0.700000  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76
#
#           z  carat_log  table_log     y_log
# 0      2.43   0.207014   4.025352  1.605430
# 1      2.31   0.190620   4.127134  1.576915
# 2      2.31   0.586585   4.189655  1.623341
# 3      2.63   0.254642   4.077537  1.654411
# 4      2.75   0.270027   4.077537  1.677097
# ...     ...        ...        ...       ...
# 53937  3.56   0.530628   4.110874  1.899118
# 53938  3.74   0.620576   4.077537  1.962908
# 53939  3.64   0.559616   4.025352  1.927164
# 53940  3.49   0.536493   4.025352  1.908060
# 53942  3.47   0.530628   4.094345  1.911023
#
# [46203 rows x 13 columns]

# %%
traindf.isnull().sum()
#check if there are any nulls left
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth        0
# table        0
# price        0
# x            0
# y            0
# z            0
# carat_log    0
# table_log    0
# y_log        0
# dtype: int64

# %%
traindf.dtypes
#since model used is linear regression , have to turn categorical data into dummy values
# Out:
# carat         float64
# cut          category
# color        category
# clarity      category
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# carat_log     float64
# table_log     float64
# y_log         float64
# dtype: object

# %%
traindfcate = pd.get_dummies(traindf[['color','cut','clarity']],drop_first=True)
#turn categorical data in dummy values

# %%
trainscaledpands = traindf[['carat_log','depth','table_log','x' ,'y_log' ,'z' ]]
#add all numerical data into thier own dataframe

# %%
trainingset = pd.concat([trainscaledpands,traindfcate], axis=1)
#combine the dummy values and the numerical data

# %%
x_train, x_test, y_train, y_test = train_test_split(
    trainingset, traindf['price'],
    test_size=0.2,      # 20% for testing
    random_state=13     # ensures same split every run
)
#create a training and testing data set at a 4 : 1  ratio respectively and seeding the rng so that the result is alwyas the same

# %%
from sklearn.feature_selection import f_regression

f_values, p_values = f_regression(x_train, y_train)

results = pd.DataFrame({
    "Feature": x_train.columns,
    "F_value": f_values,
    "p_value": p_values
})

print(results)

#try removing cut_Good , clarity_VS1 , clarity_VS2 reduces R-Value , so they are important
# f value small , p value > 0.05 = test 
#base r-score R²: 0.8946499268372092
#cut good : R²: 0.8932239832766864
#clarity vs1 : R²: 0.8821159385412403
#vs2 : R²: 0.883297005165305
#depth : R²: 0.8952114354401373


#since depth only improves the R score , dropping depth
# Out:
#           Feature        F_value        p_value
# 0       carat_log  124838.890660   0.000000e+00
# 1           depth       3.686215   5.487166e-02
# 2       table_log     599.266078  2.695294e-131
# 3               x  136756.836660   0.000000e+00
# 4           y_log  106739.564544   0.000000e+00
# 5               z  130285.762907   0.000000e+00
# 6         color_E     384.221732   4.062229e-85
# 7         color_F      24.544897   7.291851e-07
# 8         color_G       2.779478   9.548776e-02
# 9         color_H     128.128578   1.177302e-29
# 10        color_I     348.077238   2.521030e-77
# 11        color_J     249.932624   4.104561e-56
# 12       cut_Good       0.005762   9.394929e-01
# 13      cut_Ideal     316.643721   1.537073e-70
# 14    cut_Premium     300.844222   3.981458e-67
# 15  cut_Very Good       4.146776   4.172100e-02
# 16     clarity_IF      82.857698   9.246606e-20
# 17    clarity_SI1       2.135160   1.439640e-01
# 18    clarity_SI2     607.825534  3.969973e-133
# 19    clarity_VS1       2.725310   9.877743e-02
# 20    clarity_VS2       0.037690   8.460675e-01
# 21   clarity_VVS1     327.826612   5.914576e-73
# 22   clarity_VVS2     110.558266   8.041925e-26

# %%
x_train.columns
# Out:
# Index(['carat_log', 'depth', 'table_log', 'x', 'y_log', 'z', 'color_E',
#        'color_F', 'color_G', 'color_H', 'color_I', 'color_J', 'cut_Good',
#        'cut_Ideal', 'cut_Premium', 'cut_Very Good', 'clarity_IF',
#        'clarity_SI1', 'clarity_SI2', 'clarity_VS1', 'clarity_VS2',
#        'clarity_VVS1', 'clarity_VVS2'],
#       dtype='str')

# %%
x_train = x_train.drop(['depth'] , axis = 1)
x_test = x_test.drop(['depth'] , axis = 1)

# %%
#x_train = x_train.drop(['cut_Good'], axis=1)
#x_test = x_test.drop(['cut_Good'], axis=1)

# %%
#x_train = x_train.drop(['clarity_VS1'], axis=1)
#x_test = x_test.drop(['clarity_VS1'], axis=1)

# %%
#x_train = x_train.drop(['clarity_VS2'], axis=1)
#x_test = x_test.drop(['clarity_VS2'], axis=1)

# %%
#x_train.columns

# %%
from sklearn.preprocessing import StandardScaler

num_cols = ['carat_log','table_log','x','y_log','z']

scaler = StandardScaler()
x_train[num_cols] = scaler.fit_transform(x_train[num_cols])
x_test[num_cols]  = scaler.transform(x_test[num_cols])
#scale the numerical data

# %%
#check scaled data
print(type(x_train))          # dataframe
print(x_train[num_cols].mean())  # should be ~0
print(x_train[num_cols].std())   # should be ~1
# Out:
# <class 'pandas.DataFrame'>
# carat_log   -2.137664e-16
# table_log    2.782040e-15
# x           -1.337963e-16
# y_log        7.872065e-16
# z           -2.379882e-16
# dtype: float64
# carat_log    1.000014
# table_log    1.000014
# x            1.000014
# y_log        1.000014
# z            1.000014
# dtype: float64

# %%
model = LinearRegression()

model.fit(x_train, y_train)
#training model
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
#predict

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Price',size=18)
plt.ylabel('Predicted Price',size=18)
plt.show()
#plot

# %%
r2 = model.score(x_test, y_test)

print("R²:", r2)
#check r_score
# Out:
# R²: 0.8952114354401373

# %%
import pickle

import pickle
pickle.dump(model, open('diamond_model.sav', 'wb'))

#save model
