# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
traindf = pd.read_csv('DiamondPrices.csv')
#read data from csv

# %%
traindf.columns
#check column names
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='str')

# %%
traindf = traindf.drop(columns = 'Unnamed: 0')
#drop unused column

# %%
traindf
#display table
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2        NaN       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
# 53940   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53941   0.71    Premium   NaN     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53942   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76  3.47
#
# [53943 rows x 10 columns]

# %%
traindf.describe()
#describe table
# Out:
#               carat         depth         table         price             x  \
# count  51210.000000  51262.000000  51254.000000  53943.000000  51209.000000
# mean       0.797648     61.749467     57.461613   3932.734294      5.733212
# std        0.474164      1.431262      2.234639   3989.338447      1.121856
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.720000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  51274.000000  51284.000000
# mean       5.734110      3.538269
# std        1.144095      0.706337
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.520000
# 75%        6.540000      4.030000
# max       58.900000     31.800000

# %%
traindf.drop_duplicates(keep='first', inplace = True)

# %%
traindf.isnull().sum()
#check null value
# Out:
# carat      2733
# cut        2712
# color      2722
# clarity    2673
# depth      2681
# table      2689
# price         0
# x          2734
# y          2669
# z          2659
# dtype: int64

# %%
traindf.dtypes
#check column types
# Out:
# carat      float64
# cut            str
# color          str
# clarity        str
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
traindf['carat'] = traindf['carat'].fillna(traindf['carat'].mean())
#fill empty value with mean since its a numerical value

# %%
traindf['cut'] = traindf['cut'].fillna(traindf['cut'].mode()[0])
traindf['cut'] = traindf['cut'].astype('category')
#fill empty value with mode since its a categorical value

# %%
traindf['color'] = traindf['color'].fillna(traindf['color'].mode()[0])
traindf['color'] = traindf['color'].astype('category')
#fill empty value with mode since its a categorical value

# %%
traindf['clarity'] = traindf['clarity'].fillna(traindf['clarity'].mode()[0])
traindf['clarity'] = traindf['clarity'].astype('category')
#fill empty value with mode since its a categorical value

# %%
traindf['depth'].skew()
#check skew to see if there is outlier
# Out:
# np.float64(-0.11056275149712971)

# %%
traindf['depth'] = traindf['depth'].fillna(traindf['depth'].mean())
#fill empty value with mean since its a numerical value

# %%
traindf['table'].skew()
#check skew to see if there is outlier
# Out:
# np.float64(0.8006776467217596)

# %%
traindf['table'] = traindf['table'].fillna(traindf['table'].mean())
#fill empty value with mean since its a numerical value

# %%
traindf['x'] = traindf['x'].fillna(traindf['x'].mean())
#fill empty value with mean since its a numerical value

# %%
traindf['x'].skew()
#check skew to see if there is outlier
# Out:
# np.float64(0.38751104578489265)

# %%
traindf['y'].skew()
#check skew to see if there is outlier
# Out:
# np.float64(2.538087861116122)

# %%
traindf['y'] = traindf['y'].fillna(traindf['y'].median())
#fill empty value with median since skew is large

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=traindf['y'])
plt.show()
#plot_y

# %%
traindf['y_log'] = np.log1p(traindf['y'])
#deal with outlier

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=traindf['y_log'])
plt.show()
#plot y_log

# %%
traindf['y_log'].skew()
#check skew
# Out:
# np.float64(0.02079660805688358)

# %%
traindf['z'] = traindf['z'].fillna(traindf['z'].median())
#fill empty value with median since skew is large

# %%
traindf['z'].skew()
#check skew to see if there is outlier
# Out:
# np.float64(1.6293202066325085)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=traindf['z'])
plt.show()

# %%
traindf['z_log'] = np.log1p(traindf['z'])
#deal with outlier

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=traindf['z_log'])
plt.show()
#plot z

# %%
traindf['z_log'].skew()
#check z_log skew
# Out:
# np.float64(-0.13783574652171843)

# %%
traindf
# Out:
#           carat        cut color clarity  depth  table  price     x     y  \
# 0      0.230000      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1      0.210000    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2      0.797579       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3      0.290000    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4      0.310000       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...         ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53937  0.700000  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  0.860000    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  0.750000      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
# 53940  0.710000    Premium     E     SI1   60.5   55.0   2756  5.79  5.74
# 53942  0.700000  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76
#
#           z     y_log     z_log
# 0      2.43  1.605430  1.232560
# 1      2.31  1.576915  1.196948
# 2      2.31  1.623341  1.196948
# 3      2.63  1.654411  1.289233
# 4      2.75  1.677097  1.321756
# ...     ...       ...       ...
# 53937  3.56  1.899118  1.517323
# 53938  3.74  1.962908  1.556037
# 53939  3.64  1.927164  1.534714
# 53940  3.49  1.908060  1.501853
# 53942  3.47  1.911023  1.497388
#
# [53879 rows x 12 columns]

# %%
traindf.isnull().sum()
#check if there are any nulls left
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# y_log      0
# z_log      0
# dtype: int64

# %%
traindf.dtypes
#since model used is linear regression , have to turn categorical data into dummy values
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# y_log       float64
# z_log       float64
# dtype: object

# %%
traindfcate = pd.get_dummies(traindf[['color','cut','clarity']],drop_first=True)
#turn categorical data in dummy values

# %%
trainscaledpands = traindf[['carat','depth','table','x' ,'y_log' ,'z_log' ]]
#add all numerical data into thier own dataframe

# %%
trainingset = pd.concat([trainscaledpands,traindfcate], axis=1)
#combine the dummy values and the numerical data

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(
    trainingset, traindf['price'],
    test_size=0.2,      # 20% for testing
    random_state=13     # ensures same split every run
)
#create a training and testing data set at a 4 : 1  ratio respectively and seeding the rng so that the result is alwyas the same

# %%
from sklearn.feature_selection import f_regression

f_values, p_values = f_regression(x_train, y_train)

results = pd.DataFrame({
    "Feature": x_train.columns,
    "F_value": f_values,
    "p_value": p_values
})

print(results)

#try removing cut_Good , clarity_VS1 , clarity_VS2 reduces R-Value , so they are important
# f value small , p value > 0.05 = test 
#base r-score 0.8694170616071066
#cut good - rscore dropped - 0.8689988191530713
#clarity vs1 - R²: 0.855172435330309
#vs2 : R²: 0.8567207606717991
#depth :R²: 0.8694072710502924
# Out:
#           Feature        F_value        p_value
# 0           carat  178652.101026   0.000000e+00
# 1           depth       3.564487   5.903467e-02
# 2           table     691.720122  2.966558e-151
# 3               x  125716.557255   0.000000e+00
# 4           y_log   97677.081358   0.000000e+00
# 5           z_log   86631.045215   0.000000e+00
# 6         color_E     415.413588   6.603315e-92
# 7         color_F      30.928452   2.693022e-08
# 8         color_G       4.391717   3.611974e-02
# 9         color_H     140.400808   2.442418e-32
# 10        color_I     365.564051   3.755189e-81
# 11        color_J     312.597756   1.046807e-69
# 12       cut_Good       0.438170   5.080103e-01
# 13      cut_Ideal     400.859947   9.078915e-89
# 14    cut_Premium     374.458629   4.513263e-83
# 15  cut_Very Good       4.369851   3.658603e-02
# 16     clarity_IF     103.629228   2.599152e-24
# 17    clarity_SI1       3.810202   5.094777e-02
# 18    clarity_SI2     641.484716  1.700851e-140
# 19    clarity_VS1       1.811272   1.783627e-01
# 20    clarity_VS2       0.080473   7.766585e-01
# 21   clarity_VVS1     379.685862   3.359597e-84
# 22   clarity_VVS2     114.028970   1.386423e-26

# %%
x_train.columns
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y_log', 'z_log', 'color_E', 'color_F',
#        'color_G', 'color_H', 'color_I', 'color_J', 'cut_Good', 'cut_Ideal',
#        'cut_Premium', 'cut_Very Good', 'clarity_IF', 'clarity_SI1',
#        'clarity_SI2', 'clarity_VS1', 'clarity_VS2', 'clarity_VVS1',
#        'clarity_VVS2'],
#       dtype='str')

# %%
#x_train = x_train.drop(['depth'] , axis = 1)
#x_test = x_test.drop(['depth'] , axis = 1)

# %%
#x_train.columns

# %%
from sklearn.preprocessing import StandardScaler

num_cols = ['carat','depth','table','x','y_log','z_log']

scaler = StandardScaler()
x_train[num_cols] = scaler.fit_transform(x_train[num_cols])
x_test[num_cols]  = scaler.transform(x_test[num_cols])
#scale the numerical data

# %%
#check scaled data
print(type(x_train))          # dataframe
print(x_train[num_cols].mean())  # should be ~0
print(x_train[num_cols].std())   # should be ~1
# Out:
# <class 'pandas.DataFrame'>
# carat    2.545247e-16
# table    2.077080e-16
# x       -6.725783e-17
# y_log    9.946906e-16
# z_log    8.901772e-16
# dtype: float64
# carat    1.000012
# table    1.000012
# x        1.000012
# y_log    1.000012
# z_log    1.000012
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(x_train, y_train)
#training model
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
#predict

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Price',size=18)
plt.ylabel('Predicted Price',size=18)
plt.show()
#plot

# %%
r2 = model.score(x_test, y_test)

print("R²:", r2)
#check r_score
# Out:
# R²: 0.8694072710502924
